# %%
from ultralytics import YOLO
import cv2
import easyocr
from matplotlib import pyplot as plt

# %%
license_plate_detector = YOLO("../Yolo-Models/license-plate-finetune-v1x.pt")
cap = cv2.VideoCapture("../assets/videos/vid_for_license_plates.mp4")
reader = easyocr.Reader(['en'])

# %%
ret, frame = cap.read()
license_plates = license_plate_detector(frame, verbose=False)[0]
# cv2.imshow("frame", license_plates.plot())
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
while True:
    ret, frame = cap.read()
    license_plates = license_plate_detector(frame, verbose=False)[0]
    for license_plate in license_plates.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = license_plate
        print(license_plate)
        license_plate_crop = frame[int(y1):int(y2), int(x1):int(x2), :]
        result = reader.readtext(license_plate_crop)
        # bbox, plate number, conf
        if result:
            print(result)
        print("======")
        # license_plate_crop = cv2.resize(license_plate_crop, (192, 54))
        # license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
        # _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)
        # cv2.imshow("original", license_plate_crop)
        # cv2.imshow("cropped", license_plate_crop_thresh)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
# img = cv2.imread("img.png")
# result = reader.readtext(img)
# print(result)
# Out:
# [563.3319091796875, 1174.036865234375, 760.04638671875, 1231.587646484375, 0.7474681735038757, 0.0]
# [([[np.int32(27), np.int32(7)], [197, np.int32(7)], [197, np.int32(55)], [np.int32(27), np.int32(55)]], '5379MX-Z', np.float64(0.9153936325810519))]
# ...
# [892.5548095703125, 797.2080688476562, 956.7474365234375, 817.7737426757812, 0.5334418416023254, 0.0]
# ...
# [568.720703125, 1183.805419921875, 771.5208740234375, 1238.0555419921875, 0.7694756984710693, 0.0]
# [([[np.int32(30), np.int32(6)], [np.int32(200), np.int32(6)], [np.int32(200), np.int32(54)], [np.int32(30), np.int32(54)]], '5379MX-B', np.float64(0.7557869210708832))]
# ...
# [889.0408935546875, 794.736328125, 953.0772705078125, 815.49169921875, 0.5203046202659607, 0.0]
# ...
# [574.9842529296875, 1189.469482421875, 778.0133056640625, 1246.5560302734375, 0.7350378632545471, 0.0]
# ...
